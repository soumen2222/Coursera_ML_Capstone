# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd

# %%
# Read data from file 'Canada_Postal_Data.csv' 

Canada_postal = pd.read_csv("Canada_Postal_Data.csv") 
# Preview the first 5 lines of the loaded data 
Canada_postal = Canada_postal.rename(columns = {"Postcode": "Postal Code"})
Canada_postal.drop(['Unnamed: 0'], axis=1,inplace =True)
Canada_postal.head()
# Out:
#   Postal Code       Borough                             Neighborhood
# 0         M1B   Scarborough                           Rouge, Malvern
# 1         M1C   Scarborough   Highland Creek, Rouge Hill, Port Union
# 2         M1E   Scarborough        Guildwood, Morningside, West Hill
# 3         M1G   Scarborough                                   Woburn
# 4         M1H   Scarborough                                Cedarbrae

# %%
# Read data from file 'Canada_Postal_Data.csv' 

Canada_Geospatial = pd.read_csv("Geospatial_Coordinates.csv") 
# Preview the first 5 lines of the loaded data 
Canada_Geospatial.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
    result = pd.merge(Canada_postal,
                     Canada_Geospatial[['Postal Code', 'Latitude', 'Longitude']],
                     on='Postal Code')
    result.head()
# Out:
#   Postal Code       Borough                             Neighborhood  \
# 0         M1B   Scarborough                           Rouge, Malvern
# 1         M1C   Scarborough   Highland Creek, Rouge Hill, Port Union
# 2         M1E   Scarborough        Guildwood, Morningside, West Hill
# 3         M1G   Scarborough                                   Woburn
# 4         M1H   Scarborough                                Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
result.to_csv('Canada_Postal_Lal_Lon_Data.csv')
